# %%
PyTorch = Deep Learning Framework


ANN - artificial neural network 

multiple input multiple hiden layer - 1  output y 

x1*w1 + x2+b

sygmoid - 0 ,1 

1 loss function = acu - predi // diff 
2 forwad propogation 
3 backward propogration / reverse engineering 
// replay - lib - framework -mutliple lib comb
4     gpu // cpu process 10 k  
x1 - hiden lay - hiden layer - y = 6  10 //4 weight value change






Use for:

Building neural networks

Image recognition

Natural Language Processing (NLP)

AI models

Deep learning research

PyTorch mainly consists of 2 main parts:

Tensor

Neural Network module (torch.nn)

[1,2,3]

[1,2.3],[1,2,3] 

// column and row 
         1  2  3
     1   11 12 13 21 22 23 21 22 23
     2
     2 
---------------------------------------------------------------------------------
What is a Tensor?

A Tensor is a multi-dimensional array used to store data in PyTorch.

Examples:
np.array
0D → Scalar (single value)
Example: 5

1D → Vector (list of values)
Example: [1, 2, 3]

MULTIPL
2D → Matrix (table of rows and columns)

import torch

x = torch.tensor([1,2,3,4]) //1 dimenstion role row and column 
 
 a[2]3
print(x)

import torch

x = torch.tensor([ //2 dimenstion 
    [1,2],
    [3,4]
])
a[][]
print(x)
------------------------------------------------------------------------

GPU in PyTorch

PyTorch’s biggest advantage = GPU support 
Using a GPU makes model training faster because GPUs perform parallel computations.


// cpu -  50 process - 
// gpu - 500 process - 
Device Check Code
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
Explanation

torch.cuda.is_available() → Checks whether a GPU is available or not

"cuda" → The model will use the GPU

"cpu" → If no GPU is available, it will use the CPU
---------------------------------------------------
Deep learning Step
 1.Forward pass
 2.Loss calculate
 3.Backpropagation
 4.Weight update 0.5 - 0.53 0.48 Y=MX+C
